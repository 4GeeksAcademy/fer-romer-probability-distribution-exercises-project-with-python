# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %% [markdown]
# # Distribución Normal

# %%
# TODO

from scipy.stats import norm

mean = 0
std = 1

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dnorm(x, mean, std):
    """
    Calcula la estimación puntual de la distribución normal.
    """
    result = norm.pdf(x, loc = mean, scale = std) # Probability Density Function

    return result

def pnorm(x, mean, std):
    """
    Calcula el acumulado de la distribución normal.
    """
    result = norm.cdf(x = x, loc = mean, scale = std) # Cumulative Distribution Function

    return result

def qnorm(p, mean, std):
    """
    Calcula la función cuantil a partir de la distribución normal.
    """
    result = norm.ppf(q = p, loc = mean, scale = std) # Percentage Point Function

    return result

def rnorm(n, mean, std):
    """
    Genera variables aleatorias a partir de la distribución normal.
    """
    result = norm.rvs(size = n, loc = mean, scale = std) # Random Value Sample

    return result

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

data = np.arange(-5, 5, 0.01)

pmf = dnorm(data,
             mean = mean,
               std = std) # Probability Mass Function

cdf = pnorm(data,
             mean = mean,
               std = std) # Cumulative Distribution Function

ppf = qnorm(data,
             mean = mean,
               std = std) # Percentage Point Function

fig, axs = plt.subplots(1, 3, figsize = (12,6))

# Gráfico PMF
axs[0].plot(data, pmf, "r-")
axs[0].set_title('PMF-Normal Distribution')
axs[0].set_ylabel('Density')
axs[0].set_xlabel('Value')

# Gráfico CDF
axs[1].plot(data, cdf, "b-")
axs[1].set_title('CDF-Normal Distribution')
axs[1].set_ylabel('Probability')
axs[1].set_xlabel('Value')

# Gráfico PPF
axs[2].plot(data, ppf, "g-")
axs[2].set_title('PPF-Normal Distribution')

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Distribución Uniforme

# %%
from scipy.stats import uniform

low = 0
high = 1

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dunif(x, low, high):
    """
    Calcula la estimación puntual de la distribución uniforme.
    """
    result = uniform.pdf(x, loc = low, scale = (high - low)) # Probability Density Function

    return result

def punif(q, low, high):
    """
    Calcula el acumulado de la distribución Uniforme.
    """
    result = uniform.cdf(q, loc = mean, scale = (high - low)) # Cumulative Distribution Function

    return result

def qunif(p, low, high):
    """
    Calcula la función cuantil a partir de la distribución Uniforme. 
    """
    result = uniform.ppf(p, loc = low, scale = (high - low)) # Percentage Point Function

    return result

def runif(n, low, high):
    """
    Genera variables aleatorias a partir de la distribución Uniforme.
    """
    result = uniform.rvs(size = n, loc = low, scale = (high - low)) # Random Value Sample

    return result

# %%
np.random.seed(42)

data = np.arange(-5, 5, 0.01)

pmf = dunif(data,
             low = low,
               high = high) # Probability Mass Function

cdf = punif(data,
             low = low,
               high = high) # Cumulative Distribution Function

ppf = qunif(data,
             low = low,
               high = high) # Percentage Point Function


fig, axs = plt.subplots(1, 3, figsize = (12, 6))

# Gráfico PMF
axs[0].plot(data, pmf, "r-")
axs[0].set_title('PMF-Uniform Distribution')
axs[0].set_ylabel('Density')
axs[0].set_xlabel('Value')

# Gráfico CDF
axs[1].plot(data, cdf, "b-")
axs[1].set_title('CDF-Uniform Distribution')
axs[1].set_ylabel('Probability')
axs[1].set_xlabel('Value')

# Gráfico PPF
axs[2].plot(data, ppf, "g-")
axs[2].set_title('PPF-Uniform Distribution')
axs[2].set_xlabel('Probability')
axs[2].set_ylabel('Values')

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
